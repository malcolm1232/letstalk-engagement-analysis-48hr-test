# %% [markdown]
# 1. run 1_scrape_letstalk.ipynb
# 2. 2_AnalysisFor Data Story TElling (2_AnalysisQ1.py)
# this produces:
#
# data_story_q1.html — The blog-style write-up with 5 interactive charts:
#
# Monthly new topics & posts (bar + line combo)
# Engagement depth ratio over time vs. benchmark
# Cohort retention curves (Q1 2022 → Q3 2024)
# Median hours to first reply
# Category breakdown table with mini-bars
#
# The data story is structured as 8 sections with a clear narrative arc: growth → engagement quality → retention → category gaps → response time → recommendations.
# analysis_q1.py — The Python analysis code to submit alongside it. Run it after scrape_letstalk.py and it outputs 6 CSVs covering monthly activity, cohort retention, engagement ratios, reply latency, and category stats.

# %%
data_story_q1.html — The blog-style write-up with 5 interactive charts:

Monthly new topics & posts (bar + line combo)
Engagement depth ratio over time vs. benchmark
Cohort retention curves (Q1 2022 → Q3 2024)
Median hours to first reply
Category breakdown table with mini-bars

# %%
scrape_letstalk.py
    ↓ produces letstalk_topics.csv + letstalk_posts.csv
analysis_q1.py
    ↓ computes all metrics, prints chart data arrays to terminal
data_story_q1_REAL.html
    ↓ those arrays pasted into <script> block → Chart.js renders everything
